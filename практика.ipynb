# %% [markdown]
# <a href="https://colab.research.google.com/github/Tkaheva/Python/blob/main/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Уровень 1**

# %% [markdown]
# Уровень 1.1

# %% [markdown]
# 1.Дано число. Проверьте, отрицательное оно или нет. Выведите об этом информацию в консоль

# %%
num = 9
if num >= 0:
  print('the number is positive')
else:
  print('the number is negativ')

# %% [markdown]
# 2.Дана строка. Выведите в консоль длину этой строки.

# %%
str = "hi"
print(f'lenght string: len(str)')

# %%
# Вместо cuda используйте cpu
device = torch.device("cpu")
